# %% [markdown]
# # HDBSCAN Clustering Demo
#
# This notebook demonstrates the HDBSCAN clustering algorithm implemented in Rust and exposed via `datascienceutils`.
#
# HDBSCAN (Hierarchical Density-Based Spatial Clustering of Applications with Noise) is a powerful clustering algorithm that extends DBSCAN by converting it into a hierarchical clustering algorithm, and then extracting a flat clustering based on the stability of clusters.

# %%
import numpy as np
import matplotlib.pyplot as plt
import datascienceutils as dsu
from sklearn.datasets import make_blobs, make_moons

# Configure plotting
plt.style.use('seaborn-v0_8')
np.random.seed(42)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[1], line 4
#       2 import matplotlib.pyplot as plt
#       3 import datascienceutils as dsu
# ----> 4 from sklearn.datasets import make_blobs, make_moons
#       6 # Configure plotting
#       7 plt.style.use('seaborn-v0_8')
#
# ModuleNotFoundError: No module named 'sklearn'

# %%
# !pip install numpy scikits-learn
# Out:
# Requirement already satisfied: numpy in /home/roci/playspace/data-science-utils/venv/lib/python3.13/site-packages (2.3.5)
# Collecting scikits-learn
#   Using cached scikits.learn-0.8.1.tar.gz (1.6 MB)
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... error
#   error: subprocess-exited-with-error
#
#   × Getting requirements to build wheel did not run successfully.
#   │ exit code: 1
#   ╰─> [23 lines of output]
#       Traceback (most recent call last):
#         File "/home/roci/playspace/data-science-utils/venv/lib/python3.13/site-packages/pip/_vendor/pyproject_hooks/_in_process/_in_process.py", line 389, in <module>
#           main()
#           ~~~~^^
#         File "/home/roci/playspace/data-science-utils/venv/lib/python3.13/site-packages/pip/_vendor/pyproject_hooks/_in_process/_in_process.py", line 373, in main
#           json_out["return_val"] = hook(**hook_input["kwargs"])
#                                    ~~~~^^^^^^^^^^^^^^^^^^^^^^^^
#         File "/home/roci/playspace/data-science-utils/venv/lib/python3.13/site-packages/pip/_vendor/pyproject_hooks/_in_process/_in_process.py", line 143, in get_requires_for_build_wheel
#           return hook(config_settings)
#         File "/tmp/pip-build-env-vm2zpo8j/overlay/lib/python3.13/site-packages/setuptools/build_meta.py", line 331, in get_requires_for_build_wheel
#           return self._get_build_requires(config_settings, requirements=[])
#                  ~~~~~~~~~~~~~~~~~~~~~~~~^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#         File "/tmp/pip-build-env-vm2zpo8j/overlay/lib/python3.13/site-packages/setuptools/build_meta.py", line 301, in _get_build_requires
#           self.run_setup()
#           ~~~~~~~~~~~~~~^^
#         File "/tmp/pip-build-env-vm2zpo8j/overlay/lib/python3.13/site-packages/setuptools/build_meta.py", line 512, in run_setup
#           super().run_setup(setup_script=setup_script)
#           ~~~~~~~~~~~~~~~~~^^^^^^^^^^^^^^^^^^^^^^^^^^^
#         File "/tmp/pip-build-env-vm2zpo8j/overlay/lib/python3.13/site-packages/setuptools/build_meta.py", line 317, in run_setup
#           exec(code, locals())
#           ~~~~^^^^^^^^^^^^^^^^
#         File "<string>", line 23, in <module>
#       ModuleNotFoundError: No module named 'numpy'
#       [end of output]
#
#   note: This error originates from a subprocess, and is likely not a problem with pip.
# ERROR: Failed to build 'scikits-learn' when getting requirements to build wheel

# %% [markdown]
# ## 1. Clustering Blobs
#
# First, let's cluster a simple dataset of blobs with varying densities.

# %%
# Generate sample data
X_blobs, y_blobs = make_blobs(n_samples=500, centers=4, cluster_std=[0.5, 1.0, 0.5, 1.5], random_state=42)

plt.figure(figsize=(10, 6))
plt.scatter(X_blobs[:, 0], X_blobs[:, 1], s=50, alpha=0.6, c='gray')
plt.title("Input Data (Blobs)")
plt.show()

# %%
# Run HDBSCAN
min_cluster_size = 20
result = dsu.hdbscan_cluster(X_blobs, min_cluster_size)

print(f"Found {result.n_clusters} clusters")
print(f"Number of noise points: {np.sum(np.array(result.labels) == -1)}")

# %%
# Visualize results
labels = np.array(result.labels)

plt.figure(figsize=(10, 6))
# Plot noise
noise_mask = labels == -1
plt.scatter(X_blobs[noise_mask, 0], X_blobs[noise_mask, 1], c='gray', s=20, alpha=0.3, label='Noise')

# Plot clusters
unique_labels = set(labels)
unique_labels.discard(-1)
colors = plt.cm.rainbow(np.linspace(0, 1, len(unique_labels)))

for k, col in zip(sorted(unique_labels), colors):
    class_member_mask = (labels == k)
    plt.scatter(X_blobs[class_member_mask, 0], X_blobs[class_member_mask, 1], 
                color=col, s=50, alpha=0.8, label=f'Cluster {k}')

plt.title(f"HDBSCAN Clustering (min_cluster_size={min_cluster_size})")
plt.legend()
plt.show()

# %% [markdown]
# ## 2. Clustering Moons
#
# Now let's try a more complex shape: two interleaving half circles (moons).

# %%
X_moons, _ = make_moons(n_samples=500, noise=0.1, random_state=42)

plt.figure(figsize=(10, 6))
plt.scatter(X_moons[:, 0], X_moons[:, 1], s=50, alpha=0.6, c='gray')
plt.title("Input Data (Moons)")
plt.show()

# %%
# Run HDBSCAN
min_cluster_size = 10
result_moons = dsu.hdbscan_cluster(X_moons, min_cluster_size)

print(f"Found {result_moons.n_clusters} clusters")

# %%
# Visualize results
labels_moons = np.array(result_moons.labels)

plt.figure(figsize=(10, 6))
# Plot noise
noise_mask = labels_moons == -1
plt.scatter(X_moons[noise_mask, 0], X_moons[noise_mask, 1], c='gray', s=20, alpha=0.3, label='Noise')

# Plot clusters
unique_labels = set(labels_moons)
unique_labels.discard(-1)
colors = plt.cm.rainbow(np.linspace(0, 1, len(unique_labels)))

for k, col in zip(sorted(unique_labels), colors):
    class_member_mask = (labels_moons == k)
    plt.scatter(X_moons[class_member_mask, 0], X_moons[class_member_mask, 1], 
                color=col, s=50, alpha=0.8, label=f'Cluster {k}')

plt.title(f"HDBSCAN Clustering on Moons (min_cluster_size={min_cluster_size})")
plt.legend()
plt.show()
