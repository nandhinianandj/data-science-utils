# %%
# Custom libraries
from datascienceutils import plotter
from datascienceutils import analyze

# Standard libraries
import json
# %matplotlib inline
import datetime
import numpy as np
import pandas as pd
import random


from bokeh.plotting import figure, show, output_file, output_notebook, ColumnDataSource
from bokeh.charts import Histogram
import bokeh
output_notebook()
# Out:
# /home/anand/.virtualenvs/dsutils/lib/python3.6/site-packages/sklearn/ensemble/weight_boosting.py:29: DeprecationWarning: numpy.core.umath_tests is an internal NumPy module and should not be imported. It will be removed in a future NumPy release.
#   from numpy.core.umath_tests import inner1d
#
# <script type="text/javascript">
#     /* BEGIN /home/anand/.virtualenvs/dsutils/lib/python3.6/site-packages/bokeh/server/static/js/bokeh.min.js */
# ...

# %%
irisDf = pd.read_csv('../data/Iris.csv')

# %%
numericalCols = irisDf.select_dtypes(include=[np.number]).columns
catCols = set(irisDf.columns) -set(numericalCols)

# %%
irisDf.describe()
# Out:
#        sepal_length  sepal_width  petal_length  petal_width
# count    150.000000   150.000000    150.000000   150.000000
# mean       5.843333     3.054000      3.758667     1.198667
# std        0.828066     0.433594      1.764420     0.763161
# min        4.300000     2.000000      1.000000     0.100000
# 25%        5.100000     2.800000      1.600000     0.300000
# 50%        5.800000     3.000000      4.350000     1.300000
# 75%        6.400000     3.300000      5.100000     1.800000
# max        7.900000     4.400000      6.900000     2.500000

# %%
irisDf.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa

# %%
irisDf.var()
# Out:
# sepal_length    0.685694
# sepal_width     0.188004
# petal_length    3.113179
# petal_width     0.582414
# dtype: float64

# %%
irisDf.skew()
# Out:
# sepal_length    0.314911
# sepal_width     0.334053
# petal_length   -0.274464
# petal_width    -0.104997
# dtype: float64

# %%
irisDf.corr()
# Out:
#               sepal_length  sepal_width  petal_length  petal_width
# sepal_length      1.000000    -0.109369      0.871754     0.817954
# sepal_width      -0.109369     1.000000     -0.420516    -0.356544
# petal_length      0.871754    -0.420516      1.000000     0.962757
# petal_width       0.817954    -0.356544      0.962757     1.000000

# %%
import itertools
for combo in itertools.combinations(numericalCols, 2):
    analyze.correlation_analyze(irisDf, combo[0], combo[1],
                                measures=['sepal_length', 'petal_length', 'petal_width', 'sepal_width'])
# Out:
# /home/anand/.virtualenvs/dsutils/lib/python3.6/site-packages/seaborn/axisgrid.py:2262: UserWarning: The `size` paramter has been renamed to `height`; please update your code.
#   warnings.warn(msg, UserWarning)
# /home/anand/.virtualenvs/dsutils/lib/python3.6/site-packages/scipy/stats/stats.py:1713: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval
# # Correlation btw Numerical Columns
# <script type="text/javascript">
#         Bokeh.$(function() {
# ...

# %%
for col in numericalCols:
    plotter.show(analyze.dist_analyze(irisDf, col, kdeplot=True, bayesian_hist=True))
for col in catCols:
    plotter.show(analyze.dist_analyze(irisDf, col, kdeplot=False, bayesian_hist=False))
# Out:
# Variance of sepal_length
# 0.6856935123042507
# Skewness of sepal_length
# 0.3149109566369728
# Anderson-Darling normality test on sepal_length
# Statistic: 0.889199
#  p-value: 0.022511
# /home/anand/.virtualenvs/dsutils/lib/python3.6/site-packages/statsmodels/stats/_adnorm.py:66: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   S = np.sum((2*i[sl1]-1.0)/N*(np.log(z)+np.log(1-z[sl2])), axis=axis)
# /home/anand/.virtualenvs/dsutils/lib/python3.6/site-packages/datascienceutils-1.2.25-py3.6.egg/datascienceutils/utils.py:332: RuntimeWarning: divide by zero encountered in log
#   fit_vec = count_vec * (np.log(count_vec) - np.log(width))
# <script type="text/javascript">
#         Bokeh.$(function() {
# ...

# %%
#irisDf.drop('filename', inplace=True, axis=1)
for col in numericalCols:
    plotter.show(analyze.dist_analyze(irisDf, col, bayesian_hist=True))
# Out:
# Variance of sepal_length
# 0.6856935123042507
# Skewness of sepal_length
# 0.3149109566369728
# Anderson-Darling normality test on sepal_length
# Statistic: 0.889199
#  p-value: 0.022511
# /home/anand/.virtualenvs/dsutils/lib/python3.6/site-packages/statsmodels/stats/_adnorm.py:66: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   S = np.sum((2*i[sl1]-1.0)/N*(np.log(z)+np.log(1-z[sl2])), axis=axis)
# /home/anand/.virtualenvs/dsutils/lib/python3.6/site-packages/datascienceutils-1.2.25-py3.6.egg/datascienceutils/utils.py:332: RuntimeWarning: divide by zero encountered in log
#   fit_vec = count_vec * (np.log(count_vec) - np.log(width))
# <script type="text/javascript">
#         Bokeh.$(function() {
# ...

# %%
analyze.regression_analyze(irisDf, numericalCols, check_vif=False, check_heteroskedasticity=False, check_dist_similarity=False)
# Out:
# /home/anand/.virtualenvs/dsutils/lib/python3.6/site-packages/datascienceutils-1.3.0-py3.6.egg/datascienceutils/analyze.py:306: FutureWarning: Method .as_matrix will be removed in a future version. Use .values instead.
# /home/anand/.virtualenvs/dsutils/lib/python3.6/site-packages/datascienceutils-1.3.0-py3.6.egg/datascienceutils/analyze.py:313: FutureWarning: Method .as_matrix will be removed in a future version. Use .values instead.
# /home/anand/.virtualenvs/dsutils/lib/python3.6/site-packages/datascienceutils-1.3.0-py3.6.egg/datascienceutils/analyze.py:306: FutureWarning: Method .as_matrix will be removed in a future version. Use .values instead.
# /home/anand/.virtualenvs/dsutils/lib/python3.6/site-packages/datascienceutils-1.3.0-py3.6.egg/datascienceutils/analyze.py:313: FutureWarning: Method .as_matrix will be removed in a future version. Use .values instead.
# ...

# %%
analyze.non_linear_regression_analyze(irisDf, numericalCols, check_vif=False, check_heteroskedasticity=False)
# Out:
# /home/anand/.virtualenvs/dsutils/lib/python3.6/site-packages/datascienceutils-1.3.0-py3.6.egg/datascienceutils/analyze.py:241: FutureWarning: Method .as_matrix will be removed in a future version. Use .values instead.
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-5-71cd82a8098c> in <module>()
# ----> 1 analyze.non_linear_regression_analyze(irisDf, numericalCols, check_vif=False, check_heteroskedasticity=False)
#
# ~/.virtualenvs/dsutils/lib/python3.6/site-packages/datascienceutils-1.3.0-py3.6.egg/datascienceutils/analyze.py in non_linear_regression_analyze(df, target_cols, trainsize, **kwargs)
#     239         import ace
#     240         model = ace.model.Model()
# --> 241         model.build_model_from_xy([df[col1].as_matrix()], [df[col2].as_matrix()])
#     242
#     243         print(" # Ace Models btw numerical cols")
#
# ...

# %%
analyze.bayesian_regression_analyze(irisDf, numericalCols)
# Out:
# WARNING (theano.tensor.blas): Using NumPy C-API based implementation for BLAS functions.
# logp = -96.673, ||grad|| = 3.29: 100%|██████████| 25/25 [00:00<00:00, 1556.14it/s]
# Multiprocess sampling (4 chains in 4 jobs)
# NUTS: [sd, x, Intercept]
# The number of effective samples is smaller than 25% for some parameters.
# logp = -201.08, ||grad|| = 0.073719: 100%|██████████| 23/23 [00:00<00:00, 1463.16it/s]
# Multiprocess sampling (4 chains in 4 jobs)
# NUTS: [sd, x, Intercept]
# The number of effective samples is smaller than 25% for some parameters.
# logp = -112.07, ||grad|| = 679.05: 100%|██████████| 21/21 [00:00<00:00, 1752.84it/s]
# Multiprocess sampling (4 chains in 4 jobs)
# NUTS: [sd, x, Intercept]
# The number of effective samples is smaller than 25% for some parameters.
# logp = -312.24, ||grad|| = 78.951: 100%|██████████| 19/19 [00:00<00:00, 2058.42it/s]
# Multiprocess sampling (4 chains in 4 jobs)
# NUTS: [sd, x, Intercept]
# ...

# %%
irisDf.head()

# %%
irisDf.tail()

# %%
irisDf['Class'] = [random.choice(range(2)) for x in range(len(irisDf))]
irisDf.head()
analyze.dimension_analyze(irisDf,group='Class')
# Out:
# /home/anand/.virtualenvs/dsutils/lib/python3.6/site-packages/hypertools/tools/df2mat.py:38: FutureWarning: Method .as_matrix will be removed in a future version. Use .values instead.
#   plot_data = df_num.as_matrix()
